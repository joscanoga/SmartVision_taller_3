# %% [markdown]
# # Seleccion de modelo y entranamiento de clasificador

# %% [markdown]
# ## Importar Librerias necesarias

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import class_weight
from PIL import Image
from SRC.modelo_clasificacion_crt import CustomClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf

# %% [markdown]
# ## Variables de entorno

# %%
carpeta_preprocesadas = 'data/preprocesadas/'
train_normal =carpeta_preprocesadas+'train/NORMAL/'
train_pneumonia =carpeta_preprocesadas+'train/PNEUMONIA/'
test_normal =carpeta_preprocesadas+'test/NORMAL/'
test_pneumonia =carpeta_preprocesadas+'test/PNEUMONIA/'
val_normal =carpeta_preprocesadas+'val/NORMAL/'
val_pneumonia =carpeta_preprocesadas+'val/PNEUMONIA/'
dir_train =carpeta_preprocesadas+'train/'
dir_test =carpeta_preprocesadas+'test/'
dir_val =carpeta_preprocesadas+'val/'
salida_caracteristicas = 'data/caracteristicas/lbp/'
train_normal_lbp =salida_caracteristicas+'lbp_train_normal.npy'
train_pneumonia_lbp =salida_caracteristicas+'lbp_train_pneumonia.npy'
test_normal_lbp =salida_caracteristicas+'lbp_test_normal.npy'
test_pneumonia_lbp =salida_caracteristicas+'lbp_test_pneumonia.npy'
val_normal_lbp =salida_caracteristicas+'lbp_val_normal.npy'
val_pneumonia_lbp =salida_caracteristicas+'lbp_val_pneumonia.npy'

# %% [markdown]
# ## cargar caracteristicas extraidas y etiquetas

# %%
df_train_normal = pd.DataFrame(np.load(train_normal_lbp))
df_train_normal['label'] = 0
df_train_pneumonia = pd.DataFrame(np.load(train_pneumonia_lbp))
df_train_pneumonia['label'] = 1
df_test_normal = pd.DataFrame(np.load(test_normal_lbp))
df_test_normal['label'] = 0
df_test_pneumonia = pd.DataFrame(np.load(test_pneumonia_lbp))
df_test_pneumonia['label'] = 1
df_val_normal = pd.DataFrame(np.load(val_normal_lbp))
df_val_normal['label'] = 0
df_val_pneumonia = pd.DataFrame(np.load(val_pneumonia_lbp))
df_val_pneumonia['label'] = 1

# %% [markdown]
# # crear df de entrenamiento y prueba

# %%
#df_train= df_train_normal + df_train_pneumonia
df_train=pd.concat([df_train_normal, df_train_pneumonia], ignore_index=True)
# ordenar aleatoriamente el dataframe
df_train = df_train.sample(frac=1).reset_index(drop=True)
df_test=pd.concat([df_test_normal, df_test_pneumonia], ignore_index=True)
df_test = df_test.sample(frac=1).reset_index(drop=True)
df_val=pd.concat([df_val_normal, df_val_pneumonia], ignore_index=True)
df_val = df_val.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ## verificacion de dimensiones de los datos para creacion de modelo

# %%
print(df_train.shape)
print(df_test.shape)
print(df_val.shape)
#capa de entrada
input_shape = (df_train.shape[1]-1,)[0]
print("Input shape:", input_shape)
# Out:
# (5216, 27)
# (624, 27)
# (16, 27)
# Input shape: 26

# %% [markdown]
# ## dividir X e y

# %%
x_train = df_train.drop('label', axis=1).values
y_train = df_train['label'].values
x_test = df_test.drop('label', axis=1).values
y_test = df_test['label'].values
x_val = df_val.drop('label', axis=1).values
y_val = df_val['label'].values

# %% [markdown]
# ## inicializar el modelo

# %%
# 1. Inicializar la clase (usa 2048 como input_shape)
classifier_manager = CustomClassifier(input_shape=input_shape)

# 2. Compilar el modelo con las métricas deseadas
classifier_manager.compile_model(learning_rate=0.001)

# %% [markdown]
# ## Estructura del modelo

# %%
classifier_manager.show_architecture()
# Out:
# --- Resumen del Modelo Clasificador Personalizado ---
# Model: "RX_Custom_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 512)            │        13,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,617 (311.00 KB)
#  Trainable params: 79,617 (311.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## ponderacion de clases

# %%
from sklearn.utils import class_weight
import numpy as np 

# --- ASUMIENDO que y_train_labels ya ha sido cargado:
# y_train_labels = np.load(etiquetas_train)
print(f"Número de etiquetas cargadas: {len(y_train)}")

# 1. Cálculo de los Pesos de Clase
# Se calcula el peso inversamente proporcional a la frecuencia de cada clase.
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_train), # Obtiene [0, 1]
    y=y_train
)

# 2. Conversión al formato de Diccionario (requerido por Keras)
# Resultado: {0: peso_normal, 1: peso_anormal}
class_weights_dict = dict(enumerate(class_weights))

print("\n--- Resultados de Ponderación ---")
print(f"Array de pesos: {class_weights}")
print(f"Diccionario de pesos (class_weights_dict): {class_weights_dict}")
print("---------------------------------")
# Out:
# Número de etiquetas cargadas: 5216
#
# --- Resultados de Ponderación ---
# Array de pesos: [1.9448173  0.67303226]
# Diccionario de pesos (class_weights_dict): {0: np.float64(1.9448173005219984), 1: np.float64(0.6730322580645162)}
# ---------------------------------

# %% [markdown]
# ## entrenamiento de modelo

# %%
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',    # Monitorea la pérdida de validación
    patience=25,            # Paciencia de 5 épocas
    restore_best_weights=True  # Restaura los mejores pesos al finalizar
)

history = classifier_manager.model.fit(
    x_train, y_train,
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict, 
    validation_data=(x_test, y_test),
    callbacks=[early_stopping_callback],
    verbose=1
)
# Out:
# Epoch 1/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7166 - auc: 0.7680 - loss: 0.5795 - precision: 0.8696 - recall: 0.7277 - val_accuracy: 0.6699 - val_auc: 0.6806 - val_loss: 0.6329 - val_precision: 0.6949 - val_recall: 0.8410
# Epoch 2/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7352 - auc: 0.8177 - loss: 0.5226 - precision: 0.8987 - recall: 0.7254 - val_accuracy: 0.6538 - val_auc: 0.7031 - val_loss: 0.6465 - val_precision: 0.7529 - val_recall: 0.6641
# Epoch 3/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7598 - auc: 0.8454 - loss: 0.4876 - precision: 0.9074 - recall: 0.7535 - val_accuracy: 0.6923 - val_auc: 0.7356 - val_loss: 0.6085 - val_precision: 0.7781 - val_recall: 0.7103
# Epoch 4/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8066 - auc: 0.8862 - loss: 0.4284 - precision: 0.9296 - recall: 0.8003 - val_accuracy: 0.7436 - val_auc: 0.7910 - val_loss: 0.5432 - val_precision: 0.7416 - val_recall: 0.9051
# Epoch 5/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8340 - auc: 0.9189 - loss: 0.3690 - precision: 0.9380 - recall: 0.8315 - val_accuracy: 0.7484 - val_auc: 0.8166 - val_loss: 0.5491 - val_precision: 0.7422 - val_recall: 0.9154
# Epoch 6/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8554 - auc: 0.9333 - loss: 0.3340 - precision: 0.9475 - recall: 0.8526 - val_accuracy: 0.7692 - val_auc: 0.8328 - val_loss: 0.5036 - val_precision: 0.7783 - val_recall: 0.8821
# Epoch 7/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8717 - auc: 0.9433 - loss: 0.3059 - precision: 0.9541 - recall: 0.8692 - val_accuracy: 0.7580 - val_auc: 0.8462 - val_loss: 0.5307 - val_precision: 0.7454 - val_recall: 0.9308
# Epoch 8/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8834 - auc: 0.9504 - loss: 0.2851 - precision: 0.9610 - recall: 0.8787 - val_accuracy: 0.7516 - val_auc: 0.8501 - val_loss: 0.5807 - val_precision: 0.7282 - val_recall: 0.9615
# Epoch 9/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8840 - auc: 0.9533 - loss: 0.2755 - precision: 0.9603 - recall: 0.8803 - val_accuracy: 0.7804 - val_auc: 0.8494 - val_loss: 0.4889 - val_precision: 0.7949 - val_recall: 0.8744
# Epoch 10/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8890 - auc: 0.9540 - loss: 0.2732 - precision: 0.9603 - recall: 0.8872 - val_accuracy: 0.7644 - val_auc: 0.8592 - val_loss: 0.4703 - val_precision: 0.8384 - val_recall: 0.7718
# Epoch 11/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8888 - auc: 0.9557 - loss: 0.2687 - precision: 0.9624 - recall: 0.8849 - val_accuracy: 0.7548 - val_auc: 0.8517 - val_loss: 0.5808 - val_precision: 0.7328 - val_recall: 0.9564
# Epoch 12/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8867 - auc: 0.9563 - loss: 0.2671 - precision: 0.9594 - recall: 0.8849 - val_accuracy: 0.7756 - val_auc: 0.8599 - val_loss: 0.4780 - val_precision: 0.8592 - val_recall: 0.7667
# Epoch 13/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8901 - auc: 0.9557 - loss: 0.2679 - precision: 0.9643 - recall: 0.8849 - val_accuracy: 0.7740 - val_auc: 0.8588 - val_loss: 0.5244 - val_precision: 0.7556 - val_recall: 0.9436
# Epoch 14/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8875 - auc: 0.9553 - loss: 0.2693 - precision: 0.9618 - recall: 0.8836 - val_accuracy: 0.7821 - val_auc: 0.8572 - val_loss: 0.4834 - val_precision: 0.7981 - val_recall: 0.8718
# Epoch 15/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8940 - auc: 0.9577 - loss: 0.2614 - precision: 0.9674 - recall: 0.8872 - val_accuracy: 0.7837 - val_auc: 0.8598 - val_loss: 0.4706 - val_precision: 0.7986 - val_recall: 0.8744
# Epoch 16/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8890 - auc: 0.9560 - loss: 0.2675 - precision: 0.9627 - recall: 0.8849 - val_accuracy: 0.7580 - val_auc: 0.8604 - val_loss: 0.5397 - val_precision: 0.7395 - val_recall: 0.9462
# Epoch 17/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8921 - auc: 0.9577 - loss: 0.2617 - precision: 0.9628 - recall: 0.8890 - val_accuracy: 0.7853 - val_auc: 0.8605 - val_loss: 0.4883 - val_precision: 0.7807 - val_recall: 0.9128
# Epoch 18/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8944 - auc: 0.9590 - loss: 0.2575 - precision: 0.9642 - recall: 0.8908 - val_accuracy: 0.7869 - val_auc: 0.8592 - val_loss: 0.5039 - val_precision: 0.7763 - val_recall: 0.9256
# Epoch 19/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8946 - auc: 0.9593 - loss: 0.2567 - precision: 0.9663 - recall: 0.8890 - val_accuracy: 0.7788 - val_auc: 0.8604 - val_loss: 0.4890 - val_precision: 0.8073 - val_recall: 0.8487
# Epoch 20/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8953 - auc: 0.9582 - loss: 0.2600 - precision: 0.9635 - recall: 0.8929 - val_accuracy: 0.7853 - val_auc: 0.8638 - val_loss: 0.4879 - val_precision: 0.7723 - val_recall: 0.9308
# Epoch 21/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8944 - auc: 0.9586 - loss: 0.2579 - precision: 0.9655 - recall: 0.8895 - val_accuracy: 0.7740 - val_auc: 0.8626 - val_loss: 0.4648 - val_precision: 0.8105 - val_recall: 0.8333
# Epoch 22/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8949 - auc: 0.9594 - loss: 0.2550 - precision: 0.9671 - recall: 0.8888 - val_accuracy: 0.7901 - val_auc: 0.8627 - val_loss: 0.5072 - val_precision: 0.7785 - val_recall: 0.9282
# Epoch 23/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8940 - auc: 0.9585 - loss: 0.2587 - precision: 0.9650 - recall: 0.8895 - val_accuracy: 0.7756 - val_auc: 0.8632 - val_loss: 0.4578 - val_precision: 0.8125 - val_recall: 0.8333
# Epoch 24/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8921 - auc: 0.9580 - loss: 0.2613 - precision: 0.9626 - recall: 0.8893 - val_accuracy: 0.7869 - val_auc: 0.8621 - val_loss: 0.4847 - val_precision: 0.7981 - val_recall: 0.8821
# Epoch 25/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8926 - auc: 0.9592 - loss: 0.2566 - precision: 0.9649 - recall: 0.8877 - val_accuracy: 0.7804 - val_auc: 0.8649 - val_loss: 0.4539 - val_precision: 0.8063 - val_recall: 0.8538
# Epoch 26/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8924 - auc: 0.9590 - loss: 0.2573 - precision: 0.9641 - recall: 0.8883 - val_accuracy: 0.7901 - val_auc: 0.8636 - val_loss: 0.5078 - val_precision: 0.7726 - val_recall: 0.9410
# Epoch 27/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8965 - auc: 0.9615 - loss: 0.2502 - precision: 0.9657 - recall: 0.8924 - val_accuracy: 0.7837 - val_auc: 0.8572 - val_loss: 0.5328 - val_precision: 0.7766 - val_recall: 0.9179
# Epoch 28/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8934 - auc: 0.9593 - loss: 0.2565 - precision: 0.9637 - recall: 0.8901 - val_accuracy: 0.7901 - val_auc: 0.8633 - val_loss: 0.4785 - val_precision: 0.8019 - val_recall: 0.8821
# Epoch 29/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8907 - auc: 0.9595 - loss: 0.2555 - precision: 0.9654 - recall: 0.8846 - val_accuracy: 0.7500 - val_auc: 0.8527 - val_loss: 0.6620 - val_precision: 0.7199 - val_recall: 0.9821
# Epoch 30/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8965 - auc: 0.9570 - loss: 0.2628 - precision: 0.9667 - recall: 0.8914 - val_accuracy: 0.7837 - val_auc: 0.8631 - val_loss: 0.4960 - val_precision: 0.7878 - val_recall: 0.8949
# Epoch 31/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8917 - auc: 0.9585 - loss: 0.2599 - precision: 0.9623 - recall: 0.8890 - val_accuracy: 0.7740 - val_auc: 0.8629 - val_loss: 0.4730 - val_precision: 0.8105 - val_recall: 0.8333
# Epoch 32/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8978 - auc: 0.9613 - loss: 0.2502 - precision: 0.9673 - recall: 0.8926 - val_accuracy: 0.7628 - val_auc: 0.8648 - val_loss: 0.5643 - val_precision: 0.7401 - val_recall: 0.9564
# Epoch 33/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8961 - auc: 0.9601 - loss: 0.2527 - precision: 0.9646 - recall: 0.8929 - val_accuracy: 0.7756 - val_auc: 0.8630 - val_loss: 0.4680 - val_precision: 0.8109 - val_recall: 0.8359
# Epoch 34/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9007 - auc: 0.9607 - loss: 0.2492 - precision: 0.9706 - recall: 0.8934 - val_accuracy: 0.7917 - val_auc: 0.8648 - val_loss: 0.4725 - val_precision: 0.8110 - val_recall: 0.8692
# Epoch 35/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8957 - auc: 0.9595 - loss: 0.2548 - precision: 0.9664 - recall: 0.8906 - val_accuracy: 0.7933 - val_auc: 0.8643 - val_loss: 0.5059 - val_precision: 0.7747 - val_recall: 0.9436
# Epoch 36/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9028 - auc: 0.9639 - loss: 0.2417 - precision: 0.9686 - recall: 0.8983 - val_accuracy: 0.7853 - val_auc: 0.8663 - val_loss: 0.4891 - val_precision: 0.7747 - val_recall: 0.9256
# Epoch 37/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8969 - auc: 0.9596 - loss: 0.2556 - precision: 0.9628 - recall: 0.8957 - val_accuracy: 0.7901 - val_auc: 0.8658 - val_loss: 0.5040 - val_precision: 0.7821 - val_recall: 0.9205
# Epoch 38/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8946 - auc: 0.9595 - loss: 0.2560 - precision: 0.9653 - recall: 0.8901 - val_accuracy: 0.7788 - val_auc: 0.8649 - val_loss: 0.4674 - val_precision: 0.8103 - val_recall: 0.8436
# Epoch 39/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9013 - auc: 0.9632 - loss: 0.2423 - precision: 0.9685 - recall: 0.8963 - val_accuracy: 0.7788 - val_auc: 0.8677 - val_loss: 0.4561 - val_precision: 0.8134 - val_recall: 0.8385
# Epoch 40/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8947 - auc: 0.9624 - loss: 0.2468 - precision: 0.9650 - recall: 0.8906 - val_accuracy: 0.7837 - val_auc: 0.8651 - val_loss: 0.5059 - val_precision: 0.7865 - val_recall: 0.8974
# Epoch 41/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8995 - auc: 0.9639 - loss: 0.2419 - precision: 0.9674 - recall: 0.8950 - val_accuracy: 0.7580 - val_auc: 0.8657 - val_loss: 0.5675 - val_precision: 0.7348 - val_recall: 0.9590
# Epoch 42/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8999 - auc: 0.9626 - loss: 0.2440 - precision: 0.9682 - recall: 0.8947 - val_accuracy: 0.7981 - val_auc: 0.8624 - val_loss: 0.5201 - val_precision: 0.7946 - val_recall: 0.9128
# Epoch 43/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9049 - auc: 0.9631 - loss: 0.2413 - precision: 0.9721 - recall: 0.8978 - val_accuracy: 0.7965 - val_auc: 0.8688 - val_loss: 0.4863 - val_precision: 0.7929 - val_recall: 0.9128
# Epoch 44/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9005 - auc: 0.9626 - loss: 0.2453 - precision: 0.9677 - recall: 0.8960 - val_accuracy: 0.7804 - val_auc: 0.8677 - val_loss: 0.4747 - val_precision: 0.8155 - val_recall: 0.8385
# Epoch 45/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8993 - auc: 0.9616 - loss: 0.2478 - precision: 0.9681 - recall: 0.8939 - val_accuracy: 0.7869 - val_auc: 0.8652 - val_loss: 0.5457 - val_precision: 0.7660 - val_recall: 0.9487
# Epoch 46/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9016 - auc: 0.9642 - loss: 0.2382 - precision: 0.9696 - recall: 0.8957 - val_accuracy: 0.7837 - val_auc: 0.8675 - val_loss: 0.5215 - val_precision: 0.7673 - val_recall: 0.9385
# Epoch 47/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8951 - auc: 0.9616 - loss: 0.2476 - precision: 0.9666 - recall: 0.8895 - val_accuracy: 0.7837 - val_auc: 0.8663 - val_loss: 0.4763 - val_precision: 0.8102 - val_recall: 0.8538
# Epoch 48/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8993 - auc: 0.9619 - loss: 0.2473 - precision: 0.9645 - recall: 0.8975 - val_accuracy: 0.7869 - val_auc: 0.8651 - val_loss: 0.4976 - val_precision: 0.7941 - val_recall: 0.8897
# Epoch 49/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8986 - auc: 0.9627 - loss: 0.2432 - precision: 0.9715 - recall: 0.8895 - val_accuracy: 0.7516 - val_auc: 0.8617 - val_loss: 0.6291 - val_precision: 0.7264 - val_recall: 0.9667
# Epoch 50/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8957 - auc: 0.9602 - loss: 0.2530 - precision: 0.9641 - recall: 0.8929 - val_accuracy: 0.7965 - val_auc: 0.8683 - val_loss: 0.4742 - val_precision: 0.8009 - val_recall: 0.8974

# %%
# 1. Obtener las probabilidades (0 a 1)
y_pred_proba = classifier_manager.model.predict(x_test)

# 2. Convertir las probabilidades a clases binarias (0 o 1)
# Usamos el umbral estándar de 0.5. (Puedes ajustar este umbral si es necesario)
y_pred = (y_pred_proba > 0.5).astype(int) 

# Las etiquetas de clase (para el gráfico)
class_names = ['Normal (0)', 'Anormal (1)']
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 241ms/step

# %%
# 3. Calcular la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

print("Matriz de Confusión calculada:\n", cm)


# 4. Visualizar la matriz
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, 
    display_labels=class_names
)

plt.figure(figsize=(8, 8))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Matriz de Confusión en el Conjunto de Prueba')
plt.show()
# Out:
# Matriz de Confusión calculada:
#  [[154  80]
#  [ 57 333]]

# %%
#metricas Accuracy, Precision, Recall, F1-Score 
report = classification_report(y_test, y_pred, target_names=class_names)
print("Reporte de Clasificación:\n", report)
# Out:
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#   Normal (0)       0.73      0.66      0.69       234
#  Anormal (1)       0.81      0.85      0.83       390
#
#     accuracy                           0.78       624
#    macro avg       0.77      0.76      0.76       624
# weighted avg       0.78      0.78      0.78       624

# %% [markdown]
# ## SVM

# %%
svm_classifier = SVC(kernel='linear', probability=True)
svm_classifier.fit(x_train, y_train)
y_svm_pred = svm_classifier.predict(x_test)

# %% [markdown]
# ### metricas y matriz de confusion

# %%
## metricas

print("Reporte de Clasificación\n")
class_names = ['Normal (0)', 'Anormal (1)']
print(classification_report(y_test, y_svm_pred, target_names=class_names))
# Out:
# Reporte de Clasificación
#
#               precision    recall  f1-score   support
#
#   Normal (0)       0.85      0.17      0.28       234
#  Anormal (1)       0.66      0.98      0.79       390
#
#     accuracy                           0.68       624
#    macro avg       0.76      0.57      0.53       624
# weighted avg       0.73      0.68      0.60       624

# %%
cm = confusion_matrix(y_test, y_svm_pred)

print("Matriz de Confusión calculada para SVM:\n", cm)


# 4. Visualizar la matriz
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, 
    display_labels=class_names
)

plt.figure(figsize=(8, 8))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Matriz de Confusión en el Conjunto de Prueba')
plt.show()
# Out:
# Matriz de Confusión calculada para SVM:
#  [[ 39 195]
#  [  7 383]]

# %% [markdown]
# ## knn

# %%
##knn con optimizacion de parametro k
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(x_train, y_train)
y_knn_pred = knn_classifier.predict(x_test)
## metricas
print("Reporte de Clasificación para KNN:\n")
class_names = ['Normal (0)', 'Anormal (1)']
print(classification_report(y_test, y_knn_pred, target_names=class_names))
cm = confusion_matrix(y_test, y_knn_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión para KNN")
plt.show()
# Out:
# Reporte de Clasificación para KNN:
#
#               precision    recall  f1-score   support
#
#   Normal (0)       0.88      0.42      0.57       234
#  Anormal (1)       0.74      0.97      0.84       390
#
#     accuracy                           0.76       624
#    macro avg       0.81      0.69      0.70       624
# weighted avg       0.79      0.76      0.74       624

# %% [markdown]
# ## Random Forest

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(x_train, y_train)
y_rf_pred = rf_classifier.predict(x_test)
## metricas
print("Reporte de Clasificación para Random Forest:\n")
class_names = ['Normal (0)', 'Anormal (1)']
print(classification_report(y_test, y_rf_pred, target_names=class_names))
cm = confusion_matrix(y_test, y_rf_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión para Random Forest")
plt.show()
# Out:
# Reporte de Clasificación para Random Forest:
#
#               precision    recall  f1-score   support
#
#   Normal (0)       0.92      0.37      0.53       234
#  Anormal (1)       0.72      0.98      0.83       390
#
#     accuracy                           0.75       624
#    macro avg       0.82      0.67      0.68       624
# weighted avg       0.80      0.75      0.72       624
