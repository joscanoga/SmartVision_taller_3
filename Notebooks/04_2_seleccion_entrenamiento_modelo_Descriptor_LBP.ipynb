# %% [markdown]
# # Seleccion de modelo y entranamiento de clasificador

# %% [markdown]
# ## Importar Librerias necesarias

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import class_weight
from PIL import Image
from SRC.modelo_clasificacion_crt import CustomClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
# Out:
# 2025-12-02 04:15:32.537127: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Variables de entorno

# %%
carpeta_preprocesadas = 'data/preprocesadas/'
train_normal =carpeta_preprocesadas+'train/NORMAL/'
train_pneumonia =carpeta_preprocesadas+'train/PNEUMONIA/'
test_normal =carpeta_preprocesadas+'test/NORMAL/'
test_pneumonia =carpeta_preprocesadas+'test/PNEUMONIA/'
val_normal =carpeta_preprocesadas+'val/NORMAL/'
val_pneumonia =carpeta_preprocesadas+'val/PNEUMONIA/'
dir_train =carpeta_preprocesadas+'train/'
dir_test =carpeta_preprocesadas+'test/'
dir_val =carpeta_preprocesadas+'val/'
salida_caracteristicas = 'data/caracteristicas/lbp/'
train_normal_lbp =salida_caracteristicas+'lbp_train_normal.npy'
train_pneumonia_lbp =salida_caracteristicas+'lbp_train_pneumonia.npy'
test_normal_lbp =salida_caracteristicas+'lbp_test_normal.npy'
test_pneumonia_lbp =salida_caracteristicas+'lbp_test_pneumonia.npy'
val_normal_lbp =salida_caracteristicas+'lbp_val_normal.npy'
val_pneumonia_lbp =salida_caracteristicas+'lbp_val_pneumonia.npy'

# %% [markdown]
# ## cargar caracteristicas extraidas y etiquetas

# %%
df_train_normal = pd.DataFrame(np.load(train_normal_lbp))
df_train_normal['label'] = 0
df_train_pneumonia = pd.DataFrame(np.load(train_pneumonia_lbp))
df_train_pneumonia['label'] = 1
df_test_normal = pd.DataFrame(np.load(test_normal_lbp))
df_test_normal['label'] = 0
df_test_pneumonia = pd.DataFrame(np.load(test_pneumonia_lbp))
df_test_pneumonia['label'] = 1
df_val_normal = pd.DataFrame(np.load(val_normal_lbp))
df_val_normal['label'] = 0
df_val_pneumonia = pd.DataFrame(np.load(val_pneumonia_lbp))
df_val_pneumonia['label'] = 1

# %% [markdown]
# # crear df de entrenamiento y prueba

# %%
#df_train= df_train_normal + df_train_pneumonia
df_train=pd.concat([df_train_normal, df_train_pneumonia], ignore_index=True)
# ordenar aleatoriamente el dataframe
df_train = df_train.sample(frac=1).reset_index(drop=True)
df_test=pd.concat([df_test_normal, df_test_pneumonia], ignore_index=True)
df_test = df_test.sample(frac=1).reset_index(drop=True)
df_val=pd.concat([df_val_normal, df_val_pneumonia], ignore_index=True)
df_val = df_val.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ## verificacion de dimensiones de los datos para creacion de modelo

# %%
print(df_train.shape)
print(df_test.shape)
print(df_val.shape)
#capa de entrada
input_shape = (df_train.shape[1]-1,)[0]
print("Input shape:", input_shape)
# Out:
# (5216, 27)
# (624, 27)
# (16, 27)
# Input shape: 26

# %% [markdown]
# ## dividir X e y

# %%
x_train = df_train.drop('label', axis=1).values
y_train = df_train['label'].values
x_test = df_test.drop('label', axis=1).values
y_test = df_test['label'].values
x_val = df_val.drop('label', axis=1).values
y_val = df_val['label'].values

# %% [markdown]
# ## inicializar el modelo

# %%
# 1. Inicializar la clase (usa 2048 como input_shape)
classifier_manager = CustomClassifier(input_shape=input_shape)

# 2. Compilar el modelo con las métricas deseadas
classifier_manager.compile_model(learning_rate=0.001)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764649128.005589     806 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# ## Estructura del modelo

# %%
classifier_manager.show_architecture()
# Out:
# --- Resumen del Modelo Clasificador Personalizado ---
# Model: "RX_Custom_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │        13,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,617 (311.00 KB)
#  Trainable params: 79,617 (311.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## ponderacion de clases

# %%
from sklearn.utils import class_weight
import numpy as np 

# --- ASUMIENDO que y_train_labels ya ha sido cargado:
# y_train_labels = np.load(etiquetas_train)
print(f"Número de etiquetas cargadas: {len(y_train)}")

# 1. Cálculo de los Pesos de Clase
# Se calcula el peso inversamente proporcional a la frecuencia de cada clase.
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_train), # Obtiene [0, 1]
    y=y_train
)

# 2. Conversión al formato de Diccionario (requerido por Keras)
# Resultado: {0: peso_normal, 1: peso_anormal}
class_weights_dict = dict(enumerate(class_weights))

print("\n--- Resultados de Ponderación ---")
print(f"Array de pesos: {class_weights}")
print(f"Diccionario de pesos (class_weights_dict): {class_weights_dict}")
print("---------------------------------")
# Out:
# Número de etiquetas cargadas: 5216
#
# --- Resultados de Ponderación ---
# Array de pesos: [1.9448173  0.67303226]
# Diccionario de pesos (class_weights_dict): {0: np.float64(1.9448173005219984), 1: np.float64(0.6730322580645162)}
# ---------------------------------

# %% [markdown]
# ## entrenamiento de modelo

# %%
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',    # Monitorea la pérdida de validación
    patience=25,            # Paciencia de 5 épocas
    restore_best_weights=True  # Restaura los mejores pesos al finalizar
)

history = classifier_manager.model.fit(
    x_train, y_train,
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict, 
    validation_data=(x_test, y_test),
    callbacks=[early_stopping_callback],
    verbose=1
)
# Out:
# Epoch 1/150
# 2025-12-02 04:20:44.316333: I external/local_xla/xla/service/service.cc:163] XLA service 0x7fe7f8006ed0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-02 04:20:44.316386: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-12-02 04:20:44.374934: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-02 04:20:44.648276: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 2025-12-02 04:20:44.759746: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-02 04:20:44.648276: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 2025-12-02 04:20:44.759746: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-02 04:20:45.900481: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_775', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-12-02 04:20:45.900481: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_775', 520 bytes spill stores, 520 bytes spill loads
#  43/163 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7698 - auc: 0.7018 - loss: 0.6507 - precision: 0.7949 - recall: 0.9424
# I0000 00:00:1764649247.500546     889 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.7281 - auc: 0.7719 - loss: 0.5766 - precision: 0.8612 - recall: 0.7559 - val_accuracy: 0.6554 - val_auc: 0.6813 - val_loss: 0.6502 - val_precision: 0.7437 - val_recall: 0.6846
# Epoch 2/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.7281 - auc: 0.7719 - loss: 0.5766 - precision: 0.8612 - recall: 0.7559 - val_accuracy: 0.6554 - val_auc: 0.6813 - val_loss: 0.6502 - val_precision: 0.7437 - val_recall: 0.6846
# Epoch 2/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7416 - auc: 0.8283 - loss: 0.5095 - precision: 0.8995 - recall: 0.7342 - val_accuracy: 0.6891 - val_auc: 0.7080 - val_loss: 0.6430 - val_precision: 0.7016 - val_recall: 0.8744
# Epoch 3/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7416 - auc: 0.8283 - loss: 0.5095 - precision: 0.8995 - recall: 0.7342 - val_accuracy: 0.6891 - val_auc: 0.7080 - val_loss: 0.6430 - val_precision: 0.7016 - val_recall: 0.8744
# Epoch 3/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7650 - auc: 0.8534 - loss: 0.4756 - precision: 0.9102 - recall: 0.7585 - val_accuracy: 0.7083 - val_auc: 0.7472 - val_loss: 0.5767 - val_precision: 0.7291 - val_recall: 0.8487
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7650 - auc: 0.8534 - loss: 0.4756 - precision: 0.9102 - recall: 0.7585 - val_accuracy: 0.7083 - val_auc: 0.7472 - val_loss: 0.5767 - val_precision: 0.7291 - val_recall: 0.8487
# Epoch 4/150
# Epoch 4/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8035 - auc: 0.8924 - loss: 0.4183 - precision: 0.9226 - recall: 0.8028 - val_accuracy: 0.7356 - val_auc: 0.7851 - val_loss: 0.5499 - val_precision: 0.7563 - val_recall: 0.8513
# Epoch 5/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8035 - auc: 0.8924 - loss: 0.4183 - precision: 0.9226 - recall: 0.8028 - val_accuracy: 0.7356 - val_auc: 0.7851 - val_loss: 0.5499 - val_precision: 0.7563 - val_recall: 0.8513
# Epoch 5/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8397 - auc: 0.9207 - loss: 0.3640 - precision: 0.9398 - recall: 0.8379 - val_accuracy: 0.7500 - val_auc: 0.8246 - val_loss: 0.5247 - val_precision: 0.7468 - val_recall: 0.9077
# Epoch 6/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8397 - auc: 0.9207 - loss: 0.3640 - precision: 0.9398 - recall: 0.8379 - val_accuracy: 0.7500 - val_auc: 0.8246 - val_loss: 0.5247 - val_precision: 0.7468 - val_recall: 0.9077
# Epoch 6/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8696 - auc: 0.9410 - loss: 0.3155 - precision: 0.9537 - recall: 0.8666 - val_accuracy: 0.7676 - val_auc: 0.8363 - val_loss: 0.4916 - val_precision: 0.8101 - val_recall: 0.8205
# Epoch 7/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8696 - auc: 0.9410 - loss: 0.3155 - precision: 0.9537 - recall: 0.8666 - val_accuracy: 0.7676 - val_auc: 0.8363 - val_loss: 0.4916 - val_precision: 0.8101 - val_recall: 0.8205
# Epoch 7/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8827 - auc: 0.9495 - loss: 0.2896 - precision: 0.9589 - recall: 0.8797 - val_accuracy: 0.7772 - val_auc: 0.8510 - val_loss: 0.4710 - val_precision: 0.8243 - val_recall: 0.8179
# Epoch 8/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8827 - auc: 0.9495 - loss: 0.2896 - precision: 0.9589 - recall: 0.8797 - val_accuracy: 0.7772 - val_auc: 0.8510 - val_loss: 0.4710 - val_precision: 0.8243 - val_recall: 0.8179
# Epoch 8/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8752 - auc: 0.9458 - loss: 0.2973 - precision: 0.9559 - recall: 0.8723 - val_accuracy: 0.7853 - val_auc: 0.8527 - val_loss: 0.4732 - val_precision: 0.7963 - val_recall: 0.8821
# Epoch 9/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8752 - auc: 0.9458 - loss: 0.2973 - precision: 0.9559 - recall: 0.8723 - val_accuracy: 0.7853 - val_auc: 0.8527 - val_loss: 0.4732 - val_precision: 0.7963 - val_recall: 0.8821
# Epoch 9/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8794 - auc: 0.9500 - loss: 0.2851 - precision: 0.9572 - recall: 0.8769 - val_accuracy: 0.7660 - val_auc: 0.8502 - val_loss: 0.5236 - val_precision: 0.7618 - val_recall: 0.9103
# Epoch 10/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8794 - auc: 0.9500 - loss: 0.2851 - precision: 0.9572 - recall: 0.8769 - val_accuracy: 0.7660 - val_auc: 0.8502 - val_loss: 0.5236 - val_precision: 0.7618 - val_recall: 0.9103
# Epoch 10/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8865 - auc: 0.9547 - loss: 0.2718 - precision: 0.9594 - recall: 0.8846 - val_accuracy: 0.7676 - val_auc: 0.8503 - val_loss: 0.5610 - val_precision: 0.7495 - val_recall: 0.9436
# Epoch 11/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8865 - auc: 0.9547 - loss: 0.2718 - precision: 0.9594 - recall: 0.8846 - val_accuracy: 0.7676 - val_auc: 0.8503 - val_loss: 0.5610 - val_precision: 0.7495 - val_recall: 0.9436
# Epoch 11/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8857 - auc: 0.9566 - loss: 0.2656 - precision: 0.9612 - recall: 0.8818 - val_accuracy: 0.7821 - val_auc: 0.8574 - val_loss: 0.5047 - val_precision: 0.7797 - val_recall: 0.9077
# Epoch 12/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8857 - auc: 0.9566 - loss: 0.2656 - precision: 0.9612 - recall: 0.8818 - val_accuracy: 0.7821 - val_auc: 0.8574 - val_loss: 0.5047 - val_precision: 0.7797 - val_recall: 0.9077
# Epoch 12/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8938 - auc: 0.9575 - loss: 0.2629 - precision: 0.9647 - recall: 0.8895 - val_accuracy: 0.7644 - val_auc: 0.8565 - val_loss: 0.5955 - val_precision: 0.7425 - val_recall: 0.9538
# Epoch 13/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8938 - auc: 0.9575 - loss: 0.2629 - precision: 0.9647 - recall: 0.8895 - val_accuracy: 0.7644 - val_auc: 0.8565 - val_loss: 0.5955 - val_precision: 0.7425 - val_recall: 0.9538
# Epoch 13/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8936 - auc: 0.9578 - loss: 0.2618 - precision: 0.9647 - recall: 0.8893 - val_accuracy: 0.7853 - val_auc: 0.8596 - val_loss: 0.5046 - val_precision: 0.7771 - val_recall: 0.9205
# Epoch 14/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8936 - auc: 0.9578 - loss: 0.2618 - precision: 0.9647 - recall: 0.8893 - val_accuracy: 0.7853 - val_auc: 0.8596 - val_loss: 0.5046 - val_precision: 0.7771 - val_recall: 0.9205
# Epoch 14/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8942 - auc: 0.9578 - loss: 0.2611 - precision: 0.9637 - recall: 0.8911 - val_accuracy: 0.7756 - val_auc: 0.8636 - val_loss: 0.4543 - val_precision: 0.8222 - val_recall: 0.8179
# Epoch 15/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8942 - auc: 0.9578 - loss: 0.2611 - precision: 0.9637 - recall: 0.8911 - val_accuracy: 0.7756 - val_auc: 0.8636 - val_loss: 0.4543 - val_precision: 0.8222 - val_recall: 0.8179
# Epoch 15/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8903 - auc: 0.9541 - loss: 0.2723 - precision: 0.9635 - recall: 0.8859 - val_accuracy: 0.7484 - val_auc: 0.8624 - val_loss: 0.5495 - val_precision: 0.8845 - val_recall: 0.6872
# Epoch 16/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8903 - auc: 0.9541 - loss: 0.2723 - precision: 0.9635 - recall: 0.8859 - val_accuracy: 0.7484 - val_auc: 0.8624 - val_loss: 0.5495 - val_precision: 0.8845 - val_recall: 0.6872
# Epoch 16/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8842 - auc: 0.9546 - loss: 0.2718 - precision: 0.9616 - recall: 0.8792 - val_accuracy: 0.7885 - val_auc: 0.8621 - val_loss: 0.5151 - val_precision: 0.7745 - val_recall: 0.9333
# Epoch 17/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8842 - auc: 0.9546 - loss: 0.2718 - precision: 0.9616 - recall: 0.8792 - val_accuracy: 0.7885 - val_auc: 0.8621 - val_loss: 0.5151 - val_precision: 0.7745 - val_recall: 0.9333
# Epoch 17/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8884 - auc: 0.9527 - loss: 0.2762 - precision: 0.9616 - recall: 0.8852 - val_accuracy: 0.7821 - val_auc: 0.8604 - val_loss: 0.5112 - val_precision: 0.7679 - val_recall: 0.9333
# Epoch 18/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8884 - auc: 0.9527 - loss: 0.2762 - precision: 0.9616 - recall: 0.8852 - val_accuracy: 0.7821 - val_auc: 0.8604 - val_loss: 0.5112 - val_precision: 0.7679 - val_recall: 0.9333
# Epoch 18/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8953 - auc: 0.9599 - loss: 0.2548 - precision: 0.9672 - recall: 0.8893 - val_accuracy: 0.7804 - val_auc: 0.8628 - val_loss: 0.5269 - val_precision: 0.7652 - val_recall: 0.9359
# Epoch 19/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8953 - auc: 0.9599 - loss: 0.2548 - precision: 0.9672 - recall: 0.8893 - val_accuracy: 0.7804 - val_auc: 0.8628 - val_loss: 0.5269 - val_precision: 0.7652 - val_recall: 0.9359
# Epoch 19/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8959 - auc: 0.9602 - loss: 0.2535 - precision: 0.9648 - recall: 0.8924 - val_accuracy: 0.7676 - val_auc: 0.8589 - val_loss: 0.5556 - val_precision: 0.7455 - val_recall: 0.9538
# Epoch 20/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8959 - auc: 0.9602 - loss: 0.2535 - precision: 0.9648 - recall: 0.8924 - val_accuracy: 0.7676 - val_auc: 0.8589 - val_loss: 0.5556 - val_precision: 0.7455 - val_recall: 0.9538
# Epoch 20/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8896 - auc: 0.9570 - loss: 0.2639 - precision: 0.9619 - recall: 0.8865 - val_accuracy: 0.7821 - val_auc: 0.8651 - val_loss: 0.4833 - val_precision: 0.8692 - val_recall: 0.7667
# Epoch 21/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8896 - auc: 0.9570 - loss: 0.2639 - precision: 0.9619 - recall: 0.8865 - val_accuracy: 0.7821 - val_auc: 0.8651 - val_loss: 0.4833 - val_precision: 0.8692 - val_recall: 0.7667
# Epoch 21/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8809 - auc: 0.9545 - loss: 0.2717 - precision: 0.9573 - recall: 0.8790 - val_accuracy: 0.7821 - val_auc: 0.8627 - val_loss: 0.5156 - val_precision: 0.7635 - val_recall: 0.9436
# Epoch 22/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8809 - auc: 0.9545 - loss: 0.2717 - precision: 0.9573 - recall: 0.8790 - val_accuracy: 0.7821 - val_auc: 0.8627 - val_loss: 0.5156 - val_precision: 0.7635 - val_recall: 0.9436
# Epoch 22/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8969 - auc: 0.9600 - loss: 0.2540 - precision: 0.9670 - recall: 0.8916 - val_accuracy: 0.7724 - val_auc: 0.8639 - val_loss: 0.5505 - val_precision: 0.7520 - val_recall: 0.9487
# Epoch 23/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8969 - auc: 0.9600 - loss: 0.2540 - precision: 0.9670 - recall: 0.8916 - val_accuracy: 0.7724 - val_auc: 0.8639 - val_loss: 0.5505 - val_precision: 0.7520 - val_recall: 0.9487
# Epoch 23/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8955 - auc: 0.9612 - loss: 0.2505 - precision: 0.9635 - recall: 0.8932 - val_accuracy: 0.7804 - val_auc: 0.8663 - val_loss: 0.4532 - val_precision: 0.8155 - val_recall: 0.8385
# Epoch 24/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8955 - auc: 0.9612 - loss: 0.2505 - precision: 0.9635 - recall: 0.8932 - val_accuracy: 0.7804 - val_auc: 0.8663 - val_loss: 0.4532 - val_precision: 0.8155 - val_recall: 0.8385
# Epoch 24/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8940 - auc: 0.9589 - loss: 0.2585 - precision: 0.9650 - recall: 0.8895 - val_accuracy: 0.7885 - val_auc: 0.8669 - val_loss: 0.4808 - val_precision: 0.7780 - val_recall: 0.9256
# Epoch 25/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8940 - auc: 0.9589 - loss: 0.2585 - precision: 0.9650 - recall: 0.8895 - val_accuracy: 0.7885 - val_auc: 0.8669 - val_loss: 0.4808 - val_precision: 0.7780 - val_recall: 0.9256
# Epoch 25/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8980 - auc: 0.9596 - loss: 0.2551 - precision: 0.9650 - recall: 0.8952 - val_accuracy: 0.7788 - val_auc: 0.8671 - val_loss: 0.4848 - val_precision: 0.8663 - val_recall: 0.7641
# Epoch 26/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8980 - auc: 0.9596 - loss: 0.2551 - precision: 0.9650 - recall: 0.8952 - val_accuracy: 0.7788 - val_auc: 0.8671 - val_loss: 0.4848 - val_precision: 0.8663 - val_recall: 0.7641
# Epoch 26/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8976 - auc: 0.9598 - loss: 0.2525 - precision: 0.9694 - recall: 0.8903 - val_accuracy: 0.7853 - val_auc: 0.8643 - val_loss: 0.5281 - val_precision: 0.7645 - val_recall: 0.9487
# Epoch 27/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8976 - auc: 0.9598 - loss: 0.2525 - precision: 0.9694 - recall: 0.8903 - val_accuracy: 0.7853 - val_auc: 0.8643 - val_loss: 0.5281 - val_precision: 0.7645 - val_recall: 0.9487
# Epoch 27/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8970 - auc: 0.9624 - loss: 0.2471 - precision: 0.9678 - recall: 0.8911 - val_accuracy: 0.7869 - val_auc: 0.8632 - val_loss: 0.4864 - val_precision: 0.8082 - val_recall: 0.8641
# Epoch 28/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8970 - auc: 0.9624 - loss: 0.2471 - precision: 0.9678 - recall: 0.8911 - val_accuracy: 0.7869 - val_auc: 0.8632 - val_loss: 0.4864 - val_precision: 0.8082 - val_recall: 0.8641
# Epoch 28/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8957 - auc: 0.9613 - loss: 0.2489 - precision: 0.9677 - recall: 0.8893 - val_accuracy: 0.7981 - val_auc: 0.8662 - val_loss: 0.4887 - val_precision: 0.7933 - val_recall: 0.9154
# Epoch 29/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8957 - auc: 0.9613 - loss: 0.2489 - precision: 0.9677 - recall: 0.8893 - val_accuracy: 0.7981 - val_auc: 0.8662 - val_loss: 0.4887 - val_precision: 0.7933 - val_recall: 0.9154
# Epoch 29/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8988 - auc: 0.9624 - loss: 0.2465 - precision: 0.9663 - recall: 0.8950 - val_accuracy: 0.7692 - val_auc: 0.8660 - val_loss: 0.5448 - val_precision: 0.7421 - val_recall: 0.9667
# Epoch 30/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8988 - auc: 0.9624 - loss: 0.2465 - precision: 0.9663 - recall: 0.8950 - val_accuracy: 0.7692 - val_auc: 0.8660 - val_loss: 0.5448 - val_precision: 0.7421 - val_recall: 0.9667
# Epoch 30/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8967 - auc: 0.9603 - loss: 0.2524 - precision: 0.9670 - recall: 0.8914 - val_accuracy: 0.7756 - val_auc: 0.8667 - val_loss: 0.4967 - val_precision: 0.7615 - val_recall: 0.9333
# Epoch 31/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8967 - auc: 0.9603 - loss: 0.2524 - precision: 0.9670 - recall: 0.8914 - val_accuracy: 0.7756 - val_auc: 0.8667 - val_loss: 0.4967 - val_precision: 0.7615 - val_recall: 0.9333
# Epoch 31/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8949 - auc: 0.9612 - loss: 0.2505 - precision: 0.9656 - recall: 0.8903 - val_accuracy: 0.7692 - val_auc: 0.8644 - val_loss: 0.5330 - val_precision: 0.7480 - val_recall: 0.9513
# Epoch 32/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8949 - auc: 0.9612 - loss: 0.2505 - precision: 0.9656 - recall: 0.8903 - val_accuracy: 0.7692 - val_auc: 0.8644 - val_loss: 0.5330 - val_precision: 0.7480 - val_recall: 0.9513
# Epoch 32/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8995 - auc: 0.9598 - loss: 0.2554 - precision: 0.9687 - recall: 0.8937 - val_accuracy: 0.7740 - val_auc: 0.8662 - val_loss: 0.5199 - val_precision: 0.7525 - val_recall: 0.9513
# Epoch 33/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8995 - auc: 0.9598 - loss: 0.2554 - precision: 0.9687 - recall: 0.8937 - val_accuracy: 0.7740 - val_auc: 0.8662 - val_loss: 0.5199 - val_precision: 0.7525 - val_recall: 0.9513
# Epoch 33/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8926 - auc: 0.9614 - loss: 0.2490 - precision: 0.9623 - recall: 0.8903 - val_accuracy: 0.7788 - val_auc: 0.8622 - val_loss: 0.5552 - val_precision: 0.7571 - val_recall: 0.9513
# Epoch 34/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8926 - auc: 0.9614 - loss: 0.2490 - precision: 0.9623 - recall: 0.8903 - val_accuracy: 0.7788 - val_auc: 0.8622 - val_loss: 0.5552 - val_precision: 0.7571 - val_recall: 0.9513
# Epoch 34/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9001 - auc: 0.9629 - loss: 0.2428 - precision: 0.9669 - recall: 0.8963 - val_accuracy: 0.7933 - val_auc: 0.8666 - val_loss: 0.5199 - val_precision: 0.7771 - val_recall: 0.9385
# Epoch 35/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9001 - auc: 0.9629 - loss: 0.2428 - precision: 0.9669 - recall: 0.8963 - val_accuracy: 0.7933 - val_auc: 0.8666 - val_loss: 0.5199 - val_precision: 0.7771 - val_recall: 0.9385
# Epoch 35/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8944 - auc: 0.9610 - loss: 0.2512 - precision: 0.9655 - recall: 0.8895 - val_accuracy: 0.7949 - val_auc: 0.8663 - val_loss: 0.4643 - val_precision: 0.8061 - val_recall: 0.8846
# Epoch 36/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8944 - auc: 0.9610 - loss: 0.2512 - precision: 0.9655 - recall: 0.8895 - val_accuracy: 0.7949 - val_auc: 0.8663 - val_loss: 0.4643 - val_precision: 0.8061 - val_recall: 0.8846
# Epoch 36/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9009 - auc: 0.9617 - loss: 0.2483 - precision: 0.9690 - recall: 0.8952 - val_accuracy: 0.7885 - val_auc: 0.8688 - val_loss: 0.4627 - val_precision: 0.8042 - val_recall: 0.8744
# Epoch 37/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9009 - auc: 0.9617 - loss: 0.2483 - precision: 0.9690 - recall: 0.8952 - val_accuracy: 0.7885 - val_auc: 0.8688 - val_loss: 0.4627 - val_precision: 0.8042 - val_recall: 0.8744
# Epoch 37/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8984 - auc: 0.9616 - loss: 0.2485 - precision: 0.9686 - recall: 0.8921 - val_accuracy: 0.7917 - val_auc: 0.8623 - val_loss: 0.5300 - val_precision: 0.7851 - val_recall: 0.9179
# Epoch 38/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8984 - auc: 0.9616 - loss: 0.2485 - precision: 0.9686 - recall: 0.8921 - val_accuracy: 0.7917 - val_auc: 0.8623 - val_loss: 0.5300 - val_precision: 0.7851 - val_recall: 0.9179
# Epoch 38/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8938 - auc: 0.9615 - loss: 0.2487 - precision: 0.9640 - recall: 0.8903 - val_accuracy: 0.7933 - val_auc: 0.8636 - val_loss: 0.4977 - val_precision: 0.7843 - val_recall: 0.9231
# Epoch 39/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8938 - auc: 0.9615 - loss: 0.2487 - precision: 0.9640 - recall: 0.8903 - val_accuracy: 0.7933 - val_auc: 0.8636 - val_loss: 0.4977 - val_precision: 0.7843 - val_recall: 0.9231
# Epoch 39/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8970 - auc: 0.9631 - loss: 0.2442 - precision: 0.9667 - recall: 0.8921 - val_accuracy: 0.7628 - val_auc: 0.8654 - val_loss: 0.5788 - val_precision: 0.7373 - val_recall: 0.9641
# Epoch 40/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8970 - auc: 0.9631 - loss: 0.2442 - precision: 0.9667 - recall: 0.8921 - val_accuracy: 0.7628 - val_auc: 0.8654 - val_loss: 0.5788 - val_precision: 0.7373 - val_recall: 0.9641
# Epoch 40/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9015 - auc: 0.9634 - loss: 0.2423 - precision: 0.9656 - recall: 0.8994 - val_accuracy: 0.7933 - val_auc: 0.8674 - val_loss: 0.4980 - val_precision: 0.7736 - val_recall: 0.9462
# Epoch 41/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9015 - auc: 0.9634 - loss: 0.2423 - precision: 0.9656 - recall: 0.8994 - val_accuracy: 0.7933 - val_auc: 0.8674 - val_loss: 0.4980 - val_precision: 0.7736 - val_recall: 0.9462
# Epoch 41/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8993 - auc: 0.9641 - loss: 0.2409 - precision: 0.9676 - recall: 0.8945 - val_accuracy: 0.7853 - val_auc: 0.8674 - val_loss: 0.5254 - val_precision: 0.7656 - val_recall: 0.9462
# Epoch 42/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8993 - auc: 0.9641 - loss: 0.2409 - precision: 0.9676 - recall: 0.8945 - val_accuracy: 0.7853 - val_auc: 0.8674 - val_loss: 0.5254 - val_precision: 0.7656 - val_recall: 0.9462
# Epoch 42/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8880 - auc: 0.9574 - loss: 0.2620 - precision: 0.9621 - recall: 0.8841 - val_accuracy: 0.7901 - val_auc: 0.8677 - val_loss: 0.4873 - val_precision: 0.7809 - val_recall: 0.9231
# Epoch 43/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8880 - auc: 0.9574 - loss: 0.2620 - precision: 0.9621 - recall: 0.8841 - val_accuracy: 0.7901 - val_auc: 0.8677 - val_loss: 0.4873 - val_precision: 0.7809 - val_recall: 0.9231
# Epoch 43/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8953 - auc: 0.9615 - loss: 0.2495 - precision: 0.9669 - recall: 0.8895 - val_accuracy: 0.7901 - val_auc: 0.8664 - val_loss: 0.5112 - val_precision: 0.7738 - val_recall: 0.9385
# Epoch 44/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8953 - auc: 0.9615 - loss: 0.2495 - precision: 0.9669 - recall: 0.8895 - val_accuracy: 0.7901 - val_auc: 0.8664 - val_loss: 0.5112 - val_precision: 0.7738 - val_recall: 0.9385
# Epoch 44/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8970 - auc: 0.9633 - loss: 0.2420 - precision: 0.9675 - recall: 0.8914 - val_accuracy: 0.7869 - val_auc: 0.8623 - val_loss: 0.5272 - val_precision: 0.7787 - val_recall: 0.9205
# Epoch 45/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8970 - auc: 0.9633 - loss: 0.2420 - precision: 0.9675 - recall: 0.8914 - val_accuracy: 0.7869 - val_auc: 0.8623 - val_loss: 0.5272 - val_precision: 0.7787 - val_recall: 0.9205
# Epoch 45/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8955 - auc: 0.9617 - loss: 0.2481 - precision: 0.9680 - recall: 0.8888 - val_accuracy: 0.7692 - val_auc: 0.8696 - val_loss: 0.5507 - val_precision: 0.7412 - val_recall: 0.9692
# Epoch 46/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8955 - auc: 0.9617 - loss: 0.2481 - precision: 0.9680 - recall: 0.8888 - val_accuracy: 0.7692 - val_auc: 0.8696 - val_loss: 0.5507 - val_precision: 0.7412 - val_recall: 0.9692
# Epoch 46/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8961 - auc: 0.9632 - loss: 0.2424 - precision: 0.9690 - recall: 0.8885 - val_accuracy: 0.7564 - val_auc: 0.8583 - val_loss: 0.6680 - val_precision: 0.7306 - val_recall: 0.9667
# Epoch 47/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8961 - auc: 0.9632 - loss: 0.2424 - precision: 0.9690 - recall: 0.8885 - val_accuracy: 0.7564 - val_auc: 0.8583 - val_loss: 0.6680 - val_precision: 0.7306 - val_recall: 0.9667
# Epoch 47/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8978 - auc: 0.9621 - loss: 0.2460 - precision: 0.9670 - recall: 0.8929 - val_accuracy: 0.7548 - val_auc: 0.8670 - val_loss: 0.6055 - val_precision: 0.7274 - val_recall: 0.9718
# Epoch 48/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8978 - auc: 0.9621 - loss: 0.2460 - precision: 0.9670 - recall: 0.8929 - val_accuracy: 0.7548 - val_auc: 0.8670 - val_loss: 0.6055 - val_precision: 0.7274 - val_recall: 0.9718
# Epoch 48/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8974 - auc: 0.9611 - loss: 0.2503 - precision: 0.9683 - recall: 0.8911 - val_accuracy: 0.7949 - val_auc: 0.8714 - val_loss: 0.4680 - val_precision: 0.8032 - val_recall: 0.8897
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8974 - auc: 0.9611 - loss: 0.2503 - precision: 0.9683 - recall: 0.8911 - val_accuracy: 0.7949 - val_auc: 0.8714 - val_loss: 0.4680 - val_precision: 0.8032 - val_recall: 0.8897

# %%
# 1. Obtener las probabilidades (0 a 1)
y_pred_proba = classifier_manager.model.predict(x_test)

# 2. Convertir las probabilidades a clases binarias (0 o 1)
# Usamos el umbral estándar de 0.5. (Puedes ajustar este umbral si es necesario)
y_pred = (y_pred_proba > 0.5).astype(int) 

# Las etiquetas de clase (para el gráfico)
class_names = ['Normal (0)', 'Anormal (1)']
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step

# %%
# 3. Calcular la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

print("Matriz de Confusión calculada:\n", cm)


# 4. Visualizar la matriz
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, 
    display_labels=class_names
)

plt.figure(figsize=(8, 8))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Matriz de Confusión en el Conjunto de Prueba')
plt.show()
# Out:
# Matriz de Confusión calculada:
#  [[160  74]
#  [ 63 327]]

# %% [markdown]
# ## SVM

# %%
svm_classifier = SVC(kernel='linear', probability=True)
svm_classifier.fit(x_train, y_train)
y_svm_pred = svm_classifier.predict(x_test)

# %% [markdown]
# ### metricas y matriz de confusion

# %%
## metricas

print("Reporte de Clasificación para SVM:\n")
class_names = ['Normal (0)', 'Anormal (1)']
print(classification_report(y_test, y_svm_pred, target_names=class_names))
# Out:
# Reporte de Clasificación para SVM:
#
#               precision    recall  f1-score   support
#
#   Normal (0)       0.85      0.17      0.28       234
#  Anormal (1)       0.66      0.98      0.79       390
#
#     accuracy                           0.68       624
#    macro avg       0.76      0.57      0.53       624
# weighted avg       0.73      0.68      0.60       624

# %%
cm = confusion_matrix(y_test, y_svm_pred)

print("Matriz de Confusión calculada para SVM:\n", cm)


# 4. Visualizar la matriz
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, 
    display_labels=class_names
)

plt.figure(figsize=(8, 8))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Matriz de Confusión en el Conjunto de Prueba')
plt.show()
# Out:
# Matriz de Confusión calculada para SVM:
#  [[ 39 195]
#  [  7 383]]

# %% [markdown]
# ## knn

# %%
##knn con optimizacion de parametro k
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(x_train, y_train)
y_knn_pred = knn_classifier.predict(x_test)
## metricas
print("Reporte de Clasificación para KNN:\n")
class_names = ['Normal (0)', 'Anormal (1)']
print(classification_report(y_test, y_knn_pred, target_names=class_names))
cm = confusion_matrix(y_test, y_knn_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión para KNN")
plt.show()
# Out:
# Reporte de Clasificación para KNN:
#
#               precision    recall  f1-score   support
#
#   Normal (0)       0.88      0.42      0.57       234
#  Anormal (1)       0.74      0.97      0.84       390
#
#     accuracy                           0.76       624
#    macro avg       0.81      0.69      0.70       624
# weighted avg       0.79      0.76      0.74       624

# %% [markdown]
# ## Random Forest

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(x_train, y_train)
y_rf_pred = rf_classifier.predict(x_test)
## metricas
print("Reporte de Clasificación para Random Forest:\n")
class_names = ['Normal (0)', 'Anormal (1)']
print(classification_report(y_test, y_rf_pred, target_names=class_names))
cm = confusion_matrix(y_test, y_rf_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión para Random Forest")
plt.show()
# Out:
# Reporte de Clasificación para Random Forest:
#
#               precision    recall  f1-score   support
#
#   Normal (0)       0.89      0.39      0.54       234
#  Anormal (1)       0.73      0.97      0.83       390
#
#     accuracy                           0.75       624
#    macro avg       0.81      0.68      0.69       624
# weighted avg       0.79      0.75      0.72       624
