# %% [markdown]
# # Seleccion de modelo y entranamiento de clasificador

# %% [markdown]
# ## Importar Librerias necesarias

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import class_weight
from PIL import Image
from SRC.modelo_clasificacion_crt import CustomClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
# Out:
# 2025-12-03 02:06:34.529848: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Variables de entorno

# %%
carpeta_preprocesadas = 'data/preprocesadas/'
train_normal =carpeta_preprocesadas+'train/NORMAL/'
train_pneumonia =carpeta_preprocesadas+'train/PNEUMONIA/'
test_normal =carpeta_preprocesadas+'test/NORMAL/'
test_pneumonia =carpeta_preprocesadas+'test/PNEUMONIA/'
val_normal =carpeta_preprocesadas+'val/NORMAL/'
val_pneumonia =carpeta_preprocesadas+'val/PNEUMONIA/'
dir_train =carpeta_preprocesadas+'train/'
dir_test =carpeta_preprocesadas+'test/'
dir_val =carpeta_preprocesadas+'val/'
salida_caracteristicas = 'data/caracteristicas/restnet50/'
caracteristicas_train = salida_caracteristicas + 'X_train_features.npy'
etiquetas_train = salida_caracteristicas + 'y_train_labels.npy'
caracteristicas_test = salida_caracteristicas + 'X_test_features.npy'
etiquetas_test = salida_caracteristicas + 'y_test_labels.npy'
caracteristicas_val = salida_caracteristicas + 'X_val_features.npy'
etiquetas_val = salida_caracteristicas + 'y_val_labels.npy'

# %% [markdown]
# ## inicializar el modelo

# %%
# 1. Inicializar la clase (usa 2048 como input_shape)
classifier_manager = CustomClassifier(input_shape=2048)

# 2. Compilar el modelo con las métricas deseadas
classifier_manager.compile_model(learning_rate=0.001)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764727599.212820      35 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# ## Estructura del modelo

# %%
classifier_manager.show_architecture()
# Out:
# --- Resumen del Modelo Clasificador Personalizado ---
# Model: "RX_Custom_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,114,881 (4.25 MB)
#  Trainable params: 1,114,881 (4.25 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## cargar caracteristicas extraidas y etiquetas

# %%
x_train_features = np.load(caracteristicas_train)
y_train_labels = np.load(etiquetas_train)
x_test_features = np.load(caracteristicas_test)
y_test_labels = np.load(etiquetas_test)
x_val_features = np.load(caracteristicas_val)
y_val_labels = np.load(etiquetas_val)

# %% [markdown]
# ## ponderacion de clases

# %%
from sklearn.utils import class_weight
import numpy as np 

# --- ASUMIENDO que y_train_labels ya ha sido cargado:
# y_train_labels = np.load(etiquetas_train)
print(f"Número de etiquetas cargadas: {len(y_train_labels)}")

# 1. Cálculo de los Pesos de Clase
# Se calcula el peso inversamente proporcional a la frecuencia de cada clase.
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_train_labels), # Obtiene [0, 1]
    y=y_train_labels
)

# 2. Conversión al formato de Diccionario (requerido por Keras)
# Resultado: {0: peso_normal, 1: peso_anormal}
class_weights_dict = dict(enumerate(class_weights))

print("\n--- Resultados de Ponderación ---")
print(f"Array de pesos: {class_weights}")
print(f"Diccionario de pesos (class_weights_dict): {class_weights_dict}")
print("---------------------------------")
# Out:
# Número de etiquetas cargadas: 5216
#
# --- Resultados de Ponderación ---
# Array de pesos: [1.9448173  0.67303226]
# Diccionario de pesos (class_weights_dict): {0: np.float64(1.9448173005219984), 1: np.float64(0.6730322580645162)}
# ---------------------------------

# %% [markdown]
# ## entrenamiento de modelo

# %%
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',    # Monitorea la pérdida de validación
    patience=25,            # Paciencia de 5 épocas
    restore_best_weights=True  # Restaura los mejores pesos al finalizar
)

history = classifier_manager.model.fit(
    x_train_features, y_train_labels,
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict, 
    validation_data=(x_val_features, y_val_labels),
    callbacks=[early_stopping_callback],
    verbose=1
)
# Out:
# Epoch 1/150
# 2025-12-03 02:06:44.174669: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f5a5800b550 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-03 02:06:44.174877: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-12-03 02:06:44.263254: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-03 02:06:44.547184: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 2025-12-03 02:06:44.676830: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-03 02:06:44.676884: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-03 02:06:45.760213: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_203', 56 bytes spill stores, 56 bytes spill loads
#
# 2025-12-03 02:06:46.365159: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_793', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-12-03 02:06:46.519310: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_793', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-12-03 02:06:46.845721: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_775', 520 bytes spill stores, 520 bytes spill loads
#  41/163 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7300 - auc: 0.8160 - loss: 0.5525 - precision: 0.8662 - recall: 0.7465
# I0000 00:00:1764727608.299671     115 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.8957 - auc: 0.9618 - loss: 0.2553 - precision: 0.9641 - recall: 0.8929 - val_accuracy: 0.9375 - val_auc: 0.9844 - val_loss: 0.1924 - val_precision: 1.0000 - val_recall: 0.8750
# Epoch 2/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9444 - auc: 0.9874 - loss: 0.1383 - precision: 0.9841 - recall: 0.9404 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.1239 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 3/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9530 - auc: 0.9910 - loss: 0.1176 - precision: 0.9869 - recall: 0.9494 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.2246 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 4/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9582 - auc: 0.9923 - loss: 0.1031 - precision: 0.9888 - recall: 0.9546 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.0749 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 5/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9617 - auc: 0.9936 - loss: 0.0963 - precision: 0.9893 - recall: 0.9587 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.1958 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 6/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9640 - auc: 0.9941 - loss: 0.0897 - precision: 0.9907 - recall: 0.9605 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.1066 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 7/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9661 - auc: 0.9941 - loss: 0.0872 - precision: 0.9907 - recall: 0.9634 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0448 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 8/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9661 - auc: 0.9940 - loss: 0.0875 - precision: 0.9905 - recall: 0.9636 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0481 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 9/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9663 - auc: 0.9951 - loss: 0.0823 - precision: 0.9915 - recall: 0.9628 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0590 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 10/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9647 - auc: 0.9947 - loss: 0.0856 - precision: 0.9910 - recall: 0.9613 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0361 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 11/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9688 - auc: 0.9952 - loss: 0.0834 - precision: 0.9902 - recall: 0.9675 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.1078 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 12/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9657 - auc: 0.9940 - loss: 0.0875 - precision: 0.9915 - recall: 0.9621 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0275 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 13/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9711 - auc: 0.9961 - loss: 0.0703 - precision: 0.9918 - recall: 0.9690 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0209 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 14/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9697 - auc: 0.9959 - loss: 0.0748 - precision: 0.9913 - recall: 0.9677 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0548 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 15/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9705 - auc: 0.9954 - loss: 0.0784 - precision: 0.9931 - recall: 0.9670 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0468 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 16/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9684 - auc: 0.9957 - loss: 0.0755 - precision: 0.9934 - recall: 0.9639 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0291 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 17/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9741 - auc: 0.9962 - loss: 0.0655 - precision: 0.9947 - recall: 0.9703 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0610 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 18/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9751 - auc: 0.9967 - loss: 0.0634 - precision: 0.9955 - recall: 0.9708 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.0768 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 19/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9701 - auc: 0.9947 - loss: 0.0805 - precision: 0.9918 - recall: 0.9677 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.0804 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 20/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9741 - auc: 0.9970 - loss: 0.0637 - precision: 0.9950 - recall: 0.9701 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0430 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 21/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9680 - auc: 0.9960 - loss: 0.0722 - precision: 0.9936 - recall: 0.9631 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0233 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 22/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9764 - auc: 0.9974 - loss: 0.0581 - precision: 0.9950 - recall: 0.9732 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.0992 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 23/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9732 - auc: 0.9968 - loss: 0.0641 - precision: 0.9942 - recall: 0.9695 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.1073 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 24/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9751 - auc: 0.9964 - loss: 0.0677 - precision: 0.9919 - recall: 0.9745 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0283 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 25/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9776 - auc: 0.9973 - loss: 0.0587 - precision: 0.9934 - recall: 0.9763 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.0804 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 26/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9801 - auc: 0.9981 - loss: 0.0490 - precision: 0.9953 - recall: 0.9778 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.0971 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 27/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9787 - auc: 0.9974 - loss: 0.0555 - precision: 0.9942 - recall: 0.9770 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.0606 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 28/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9791 - auc: 0.9978 - loss: 0.0541 - precision: 0.9945 - recall: 0.9773 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.0870 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 29/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9801 - auc: 0.9980 - loss: 0.0501 - precision: 0.9948 - recall: 0.9783 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0359 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 30/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9810 - auc: 0.9980 - loss: 0.0510 - precision: 0.9942 - recall: 0.9801 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.1598 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 31/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9795 - auc: 0.9973 - loss: 0.0577 - precision: 0.9924 - recall: 0.9799 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0330 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 32/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9780 - auc: 0.9972 - loss: 0.0568 - precision: 0.9929 - recall: 0.9773 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0355 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 33/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9774 - auc: 0.9968 - loss: 0.0613 - precision: 0.9947 - recall: 0.9747 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0244 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 34/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9766 - auc: 0.9980 - loss: 0.0539 - precision: 0.9939 - recall: 0.9745 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0344 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 35/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9803 - auc: 0.9975 - loss: 0.0531 - precision: 0.9958 - recall: 0.9775 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0238 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 36/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9772 - auc: 0.9972 - loss: 0.0580 - precision: 0.9940 - recall: 0.9752 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0674 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 37/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9797 - auc: 0.9983 - loss: 0.0498 - precision: 0.9937 - recall: 0.9788 - val_accuracy: 0.9375 - val_auc: 1.0000 - val_loss: 0.1090 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 38/150
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9814 - auc: 0.9985 - loss: 0.0447 - precision: 0.9945 - recall: 0.9804 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0385 - val_precision: 1.0000 - val_recall: 1.0000

# %%
# 1. Obtener las probabilidades (0 a 1)
y_pred_proba = classifier_manager.model.predict(x_test_features)

# 2. Convertir las probabilidades a clases binarias (0 o 1)
# Usamos el umbral estándar de 0.5. (Puedes ajustar este umbral si es necesario)
y_pred = (y_pred_proba > 0.5).astype(int) 

# Las etiquetas de clase (para el gráfico)
class_names = ['Normal (0)', 'Anormal (1)']
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step

# %%
# 3. Calcular la matriz de confusión
cm = confusion_matrix(y_test_labels, y_pred)

print("Matriz de Confusión calculada:\n", cm)


# 4. Visualizar la matriz
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, 
    display_labels=class_names
)

plt.figure(figsize=(8, 8))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Matriz de Confusión en el Conjunto de Prueba')
plt.show()
# Out:
# Matriz de Confusión calculada:
#  [[167  67]
#  [  4 386]]

# %%
#metricas Accuracy, Precision, Recall, F1-Score 
report = classification_report(y_test_labels, y_pred, target_names=class_names)
print("Reporte de Clasificación:\n", report)
# Out:
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#   Normal (0)       0.98      0.71      0.82       234
#  Anormal (1)       0.85      0.99      0.92       390
#
#     accuracy                           0.89       624
#    macro avg       0.91      0.85      0.87       624
# weighted avg       0.90      0.89      0.88       624

# %% [markdown]
# ## SVM

# %%
svm_classifier = SVC(kernel='linear', probability=True)
svm_classifier.fit(x_train_features, y_train_labels)
y_svm_pred = svm_classifier.predict(x_test_features)

# %% [markdown]
# ### metricas y matriz de confusion

# %%
## metricas

print("Reporte de Clasificación para SVM:\n")
class_names = ['Normal (0)', 'Anormal (1)']
print(classification_report(y_test_labels, y_svm_pred, target_names=class_names))
# Out:
# Reporte de Clasificación para SVM:
#
#               precision    recall  f1-score   support
#
#   Normal (0)       0.97      0.46      0.63       234
#  Anormal (1)       0.75      0.99      0.86       390
#
#     accuracy                           0.79       624
#    macro avg       0.86      0.73      0.74       624
# weighted avg       0.84      0.79      0.77       624

# %%
cm = confusion_matrix(y_test_labels, y_svm_pred)

print("Matriz de Confusión calculada para SVM:\n", cm)


# 4. Visualizar la matriz
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, 
    display_labels=class_names
)

plt.figure(figsize=(8, 8))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Matriz de Confusión en el Conjunto de Prueba')
plt.show()
# Out:
# Matriz de Confusión calculada para SVM:
#  [[108 126]
#  [  3 387]]

# %% [markdown]
# ## knn

# %%
##knn con optimizacion de parametro k
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(x_train_features, y_train_labels)
y_knn_pred = knn_classifier.predict(x_test_features)
## metricas
print("Reporte de Clasificación para KNN:\n")
class_names = ['Normal (0)', 'Anormal (1)']
print(classification_report(y_test_labels, y_knn_pred, target_names=class_names))
cm = confusion_matrix(y_test_labels, y_knn_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión para KNN")
plt.show()
# Out:
# Reporte de Clasificación para KNN:
#
#               precision    recall  f1-score   support
#
#   Normal (0)       0.97      0.54      0.69       234
#  Anormal (1)       0.78      0.99      0.87       390
#
#     accuracy                           0.82       624
#    macro avg       0.88      0.76      0.78       624
# weighted avg       0.85      0.82      0.81       624

# %% [markdown]
# ## Random Forest

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(x_train_features, y_train_labels)
y_rf_pred = rf_classifier.predict(x_test_features)
## metricas
print("Reporte de Clasificación para Random Forest:\n")
class_names = ['Normal (0)', 'Anormal (1)']
print(classification_report(y_test_labels, y_rf_pred, target_names=class_names))
cm = confusion_matrix(y_test_labels, y_rf_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión para Random Forest")
plt.show()
# Out:
# Reporte de Clasificación para Random Forest:
#
#               precision    recall  f1-score   support
#
#   Normal (0)       0.97      0.38      0.55       234
#  Anormal (1)       0.73      0.99      0.84       390
#
#     accuracy                           0.76       624
#    macro avg       0.85      0.69      0.70       624
# weighted avg       0.82      0.76      0.73       624
