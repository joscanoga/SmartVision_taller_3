# %% [markdown]
# ## 🔧 **Importación de librerías**

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\maria\appdata\roaming\python\python313\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\maria\appdata\roaming\python\python313\site-packages (from opencv-python) (2.2.6)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature.texture import graycomatrix, graycoprops
import matplotlib.pyplot as plt
import os
import cv2
import numpy as np
import random

# %% [markdown]
# ## 📥 **Variables de entorno**

# %%
carpeta_preprocesadas = '../data/preprocesadas/'
train_normal =carpeta_preprocesadas+'train/NORMAL/'
train_pneumonia =carpeta_preprocesadas+'train/PNEUMONIA/'
test_normal =carpeta_preprocesadas+'test/NORMAL/'
test_pneumonia =carpeta_preprocesadas+'test/PNEUMONIA/'
val_normal =carpeta_preprocesadas+'val/NORMAL/'
val_pneumonia =carpeta_preprocesadas+'val/PNEUMONIA/'
dir_train =carpeta_preprocesadas+'train/'
dir_test =carpeta_preprocesadas+'test/'
dir_val =carpeta_preprocesadas+'val/'
salida_caracteristicas = 'data/caracteristicas/'

# %% [markdown]
# ## 📥 **Cargar imagenes y visualizar**
#
# Seleccionamos 3 imágenes al azar de cada categoría

# %%
#display 2x3 con 3 imagenes al azar de nuemonia y 3 de normal del set de train

# Seleccionar 3 imágenes al azar de cada categoría  
normal_images = os.listdir(train_normal)
neumonia_images = os.listdir(train_pneumonia)
random_normal_images = random.sample(normal_images, 3)
random_neumonia_images = random.sample(neumonia_images, 3)

cell_size = (8, 8)
block_size = (16, 16)
block_stride = (8, 8)
num_bins = 9

# %% [markdown]
# ## ✨ **1. Momentos de Hu**
# Los Momentos de Hu son 7 valores derivados de momentos invariantes de la imagen, los cuales son:
# - Invariantes a **traslación**
# - Invariantes a **rotación**
# - Invariantes a **escala**
#
# El séptimo momento también es sensible a reflexiones.

# %%
def extraer_momentos_hu(img_gray):
    # Asegurar que sea uint8
    img_gray = img_gray.astype("uint8")

    # 1) Suavizado
    blur = cv2.GaussianBlur(img_gray, (5,5), 0)

    # 2) Binarización Otsu
    _, thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # 3) Momentos
    M = cv2.moments(thresh)
    hu = cv2.HuMoments(M).flatten()

    # 4) Log-transform
    hu_log = [-np.sign(h) * np.log10(abs(h)) if h != 0 else 0 for h in hu]

    return hu_log, thresh

# %% [markdown]
# ### 🔍 **Visualización del contorno utilizado en los momentos**

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

def extraer_momentos_hu(img_gray):
    img_gray = img_gray.astype("uint8")

    blur = cv2.GaussianBlur(img_gray, (5,5), 0)
    _, thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

    M = cv2.moments(thresh)
    hu = cv2.HuMoments(M).flatten()

    hu_log = [-np.sign(h)*np.log10(abs(h)) if h != 0 else 0 for h in hu]

    return hu_log, thresh


def mostrar_comparacion_original_vs_hu(train_normal, train_pneumonia):

    random_normal = random.sample(os.listdir(train_normal), 3)
    random_pneumonia = random.sample(os.listdir(train_pneumonia), 3)

    fig, axes = plt.subplots(4, 3, figsize=(14, 14))  
    # 4 filas:
    #   0: NORMAL original
    #   1: NORMAL procesada
    #   2: NEUMONÍA original
    #   3: NEUMONÍA procesada

    # ------ NORMAL ------
    for i, img_name in enumerate(random_normal):
        path = os.path.join(train_normal, img_name)
        img = np.array(Image.open(path).convert("L"))

        hu, thresh = extraer_momentos_hu(img)

        # Original
        axes[0, i].imshow(img, cmap="gray")
        axes[0, i].set_title(f"Normal (Original)\n{img_name}")
        axes[0, i].axis("off")

        # Procesada
        axes[1, i].imshow(thresh, cmap="gray")
        axes[1, i].set_title("Procesada (Hu)")
        axes[1, i].axis("off")

    # ------ NEUMONÍA ------
    for i, img_name in enumerate(random_pneumonia):
        path = os.path.join(train_pneumonia, img_name)
        img = np.array(Image.open(path).convert("L"))

        hu, thresh = extraer_momentos_hu(img)

        # Original
        axes[2, i].imshow(img, cmap="gray")
        axes[2, i].set_title(f"Neumonía (Original)\n{img_name}")
        axes[2, i].axis("off")

        # Procesada
        axes[3, i].imshow(thresh, cmap="gray")
        axes[3, i].set_title("Procesada (Hu)")
        axes[3, i].axis("off")

    plt.tight_layout()
    plt.show()

mostrar_comparacion_original_vs_hu(train_normal, train_pneumonia)

# %% [markdown]
# ## 🧱 **2. Gray Level Co-occurrence Matrix (GLCM)**
# GLCM analiza **cómo se relacionan los niveles de gris** según distancia y orientación.
#
# Propiedades que calculamos:
# - **Contraste**
# - **Correlación**
# - **Energía**
# - **Homogeneidad**

# %%
import sys
import skimage
print("Python:", sys.version)
print("scikit-image:", skimage.__version__)
# Out:
# Python: 3.13.1 (tags/v3.13.1:0671451, Dec  3 2024, 19:06:28) [MSC v.1942 64 bit (AMD64)]
# scikit-image: 0.25.2

# %% [markdown]
# ## 🧱 **Creamos nuestras propias funciones para GLCM**
# Esto debido a que en nuestra version de python las funciones para realizar ese proceso fueron descontinuadas.

# %%
import numpy as np

def glcm_matrix(img, distance=1, angle=0, levels=256):
    rows, cols = img.shape
    glcm = np.zeros((levels, levels), dtype=np.float64)

    # Direcciones
    dx = int(round(np.cos(angle) * distance))
    dy = int(round(np.sin(angle) * distance))

    for i in range(rows):
        for j in range(cols):
            x = i + dy
            y = j + dx
            if 0 <= x < rows and 0 <= y < cols:
                glcm[img[i,j], img[x,y]] += 1

    glcm /= glcm.sum()
    return glcm


def glcm_props(glcm):
    i, j = np.indices(glcm.shape)

    contrast = np.sum(glcm * (i - j)**2)
    energy = np.sum(glcm**2)
    homogeneity = np.sum(glcm / (1 + np.abs(i - j)))

    μ_i = np.sum(i * glcm)
    μ_j = np.sum(j * glcm)
    σ_i = np.sqrt(np.sum((i - μ_i)**2 * glcm))
    σ_j = np.sqrt(np.sum((j - μ_j)**2 * glcm))

    if σ_i == 0 or σ_j == 0:
        correlation = 1
    else:
        correlation = np.sum(((i - μ_i) * (j - μ_j) * glcm) / (σ_i * σ_j))

    return contrast, correlation, energy, homogeneity


def compute_glcm_features(img, distances=[1, 3, 5],
                          angles=[0, np.pi/4, np.pi/2, 3*np.pi/4]):
    img = img.astype(np.uint8)
    results = []

    for d in distances:
        for a in angles:
            glcm = glcm_matrix(img, distance=d, angle=a, levels=256)
            props = glcm_props(glcm)
            results.append({
                "distance": d,
                "angle": a,
                "contrast": props[0],
                "correlation": props[1],
                "energy": props[2],
                "homogeneity": props[3]
            })

    return results

# %% [markdown]
# ## 🧱 **Proceso de calculo para cada una de las imagenes con GLCM**
# Este script nos proporciona el calculo de propiedades: contraste, correlación, energía, homogeneidad.
# Realizadas en diferentes direcciones y distancias como se pidio en el trabajo.

# %%
import os
import random
import cv2
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# 1. Funciones GLCM sin scikit-image (para Python 3.13)
# -----------------------------
def glcm_matrix(img, distance=1, angle=0, levels=256):
    rows, cols = img.shape
    glcm = np.zeros((levels, levels), dtype=np.float64)

    dx = int(round(np.cos(angle) * distance))
    dy = int(round(np.sin(angle) * distance))

    for i in range(rows):
        for j in range(cols):
            x = i + dy
            y = j + dx
            if 0 <= x < rows and 0 <= y < cols:
                glcm[img[i,j], img[x,y]] += 1

    glcm /= glcm.sum()
    return glcm


def glcm_props(glcm):
    i, j = np.indices(glcm.shape)

    contrast = np.sum(glcm * (i - j)**2)
    energy = np.sum(glcm**2)
    homogeneity = np.sum(glcm / (1 + np.abs(i - j)))

    μ_i = np.sum(i * glcm)
    μ_j = np.sum(j * glcm)
    σ_i = np.sqrt(np.sum((i - μ_i)**2 * glcm))
    σ_j = np.sqrt(np.sum((j - μ_j)**2 * glcm))

    if σ_i == 0 or σ_j == 0:
        correlation = 1
    else:
        correlation = np.sum(((i - μ_i) * (j - μ_j) * glcm) / (σ_i * σ_j))

    return contrast, correlation, energy, homogeneity


def compute_glcm_features(img, distances=[1,3,5],
                          angles=[0, np.pi/4, np.pi/2, 3*np.pi/4]):

    img = img.astype(np.uint8)
    results = []

    for d in distances:
        for a in angles:
            glcm = glcm_matrix(img, distance=d, angle=a, levels=256)
            props = glcm_props(glcm)

            results.append({
                "distance": d,
                "angle": a,
                "contrast": props[0],
                "correlation": props[1],
                "energy": props[2],
                "homogeneity": props[3]
            })

    return results

# -----------------------------
# 2. Seleccionar imágenes como tú lo hiciste
# -----------------------------
normal_images = os.listdir(train_normal)
neumonia_images = os.listdir(train_pneumonia)

random_normal_images = random.sample(normal_images, 3)
random_neumonia_images = random.sample(neumonia_images, 3)

selected_images = random_normal_images + random_neumonia_images

# -----------------------------
# 3. Mostrar 2x3 imágenes
# -----------------------------
plt.figure(figsize=(10, 6))

for idx, img_name in enumerate(selected_images):
    if idx < 3:
        path = os.path.join(train_normal, img_name)
        title = "NORMAL"
    else:
        path = os.path.join(train_pneumonia, img_name)
        title = "NEUMONIA"

    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

    plt.subplot(2, 3, idx + 1)
    plt.imshow(img, cmap="gray")
    plt.title(title)
    plt.axis("off")

plt.show()

# -----------------------------
# 4. Calcular GLCM de cada imagen seleccionada
# -----------------------------
print("\n======= PROPIEDADES GLCM =======")

for idx, img_name in enumerate(selected_images):

    if idx < 3:
        path = os.path.join(train_normal, img_name)
        clase = "NORMAL"
    else:
        path = os.path.join(train_pneumonia, img_name)
        clase = "NEUMONIA"

    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

    features = compute_glcm_features(
        img,
        distances=[1, 3, 5],
        angles=[0, np.pi/4, np.pi/2, 3*np.pi/4]
    )

    print(f"\nImagen: {img_name} | Clase: {clase}")
    for f in features:
        print(f"Dist={f['distance']}, Ang={round(f['angle'],2)} | "
              f"Contrast={f['contrast']:.4f}, "
              f"Correlation={f['correlation']:.4f}, "
              f"Energy={f['energy']:.4f}, "
              f"Homogeneity={f['homogeneity']:.4f}")
# Out:
# ======= PROPIEDADES GLCM =======
#
# Imagen: NORMAL2-IM-0649-0001.jpeg | Clase: NORMAL
# Dist=1, Ang=0 | Contrast=26.7379, Correlation=0.9967, Energy=0.0539, Homogeneity=0.5667
# Dist=1, Ang=0.79 | Contrast=121.2555, Correlation=0.9852, Energy=0.0491, Homogeneity=0.4998
# Dist=1, Ang=1.57 | Contrast=100.5679, Correlation=0.9877, Energy=0.0501, Homogeneity=0.5618
# Dist=1, Ang=2.36 | Contrast=124.4178, Correlation=0.9848, Energy=0.0492, Homogeneity=0.4981
# Dist=3, Ang=0 | Contrast=129.4668, Correlation=0.9842, Energy=0.0515, Homogeneity=0.4412
# Dist=3, Ang=0.79 | Contrast=271.5278, Correlation=0.9667, Energy=0.0493, Homogeneity=0.4354
# Dist=3, Ang=1.57 | Contrast=340.8818, Correlation=0.9582, Energy=0.0483, Homogeneity=0.4438
# Dist=3, Ang=2.36 | Contrast=275.8992, Correlation=0.9662, Energy=0.0492, Homogeneity=0.4333
# Dist=5, Ang=0 | Contrast=208.6306, Correlation=0.9744, Energy=0.0500, Homogeneity=0.4021
# Dist=5, Ang=0.79 | Contrast=543.8960, Correlation=0.9328, Energy=0.0453, Homogeneity=0.3766
# Dist=5, Ang=1.57 | Contrast=568.9034, Correlation=0.9300, Energy=0.0464, Homogeneity=0.4012
# Dist=5, Ang=2.36 | Contrast=545.0084, Correlation=0.9327, Energy=0.0453, Homogeneity=0.3731
#
# Imagen: IM-0400-0001.jpeg | Clase: NORMAL
# Dist=1, Ang=0 | Contrast=39.6252, Correlation=0.9964, Energy=0.1154, Homogeneity=0.5657
# Dist=1, Ang=0.79 | Contrast=134.3469, Correlation=0.9879, Energy=0.1133, Homogeneity=0.5256
# Dist=1, Ang=1.57 | Contrast=106.0241, Correlation=0.9905, Energy=0.1151, Homogeneity=0.5682
# Dist=1, Ang=2.36 | Contrast=143.4928, Correlation=0.9871, Energy=0.1133, Homogeneity=0.5233
# Dist=3, Ang=0 | Contrast=198.2345, Correlation=0.9822, Energy=0.1121, Homogeneity=0.4757
# Dist=3, Ang=0.79 | Contrast=309.7999, Correlation=0.9721, Energy=0.1098, Homogeneity=0.4761
# Dist=3, Ang=1.57 | Contrast=379.1674, Correlation=0.9658, Energy=0.1102, Homogeneity=0.4800
# Dist=3, Ang=2.36 | Contrast=331.5521, Correlation=0.9701, Energy=0.1097, Homogeneity=0.4739
# Dist=5, Ang=0 | Contrast=336.5589, Correlation=0.9697, Energy=0.1091, Homogeneity=0.4458
# Dist=5, Ang=0.79 | Contrast=628.7896, Correlation=0.9432, Energy=0.1030, Homogeneity=0.4316
# Dist=5, Ang=1.57 | Contrast=638.3964, Correlation=0.9424, Energy=0.1058, Homogeneity=0.4481
# Dist=5, Ang=2.36 | Contrast=668.4010, Correlation=0.9396, Energy=0.1029, Homogeneity=0.4297
#
# Imagen: NORMAL2-IM-0429-0001.jpeg | Clase: NORMAL
# Dist=1, Ang=0 | Contrast=28.8792, Correlation=0.9975, Energy=0.0117, Homogeneity=0.4784
# Dist=1, Ang=0.79 | Contrast=109.9441, Correlation=0.9903, Energy=0.0096, Homogeneity=0.4096
# Dist=1, Ang=1.57 | Contrast=86.4742, Correlation=0.9924, Energy=0.0098, Homogeneity=0.4879
# Dist=1, Ang=2.36 | Contrast=111.9139, Correlation=0.9901, Energy=0.0096, Homogeneity=0.4093
# Dist=3, Ang=0 | Contrast=131.2348, Correlation=0.9884, Energy=0.0112, Homogeneity=0.3443
# Dist=3, Ang=0.79 | Contrast=274.6150, Correlation=0.9756, Energy=0.0097, Homogeneity=0.3394
# Dist=3, Ang=1.57 | Contrast=358.3798, Correlation=0.9681, Energy=0.0088, Homogeneity=0.3511
# Dist=3, Ang=2.36 | Contrast=279.3311, Correlation=0.9751, Energy=0.0097, Homogeneity=0.3387
# Dist=5, Ang=0 | Contrast=238.7121, Correlation=0.9789, Energy=0.0110, Homogeneity=0.3029
# Dist=5, Ang=0.79 | Contrast=593.5937, Correlation=0.9465, Energy=0.0084, Homogeneity=0.2747
# Dist=5, Ang=1.57 | Contrast=618.6601, Correlation=0.9443, Energy=0.0078, Homogeneity=0.3045
# Dist=5, Ang=2.36 | Contrast=604.7575, Correlation=0.9455, Energy=0.0084, Homogeneity=0.2760
#
# Imagen: person371_virus_754.jpeg | Clase: NEUMONIA
# Dist=1, Ang=0 | Contrast=17.4791, Correlation=0.9988, Energy=0.2320, Homogeneity=0.7322
# Dist=1, Ang=0.79 | Contrast=123.9655, Correlation=0.9912, Energy=0.2228, Homogeneity=0.6732
# Dist=1, Ang=1.57 | Contrast=112.4101, Correlation=0.9921, Energy=0.2246, Homogeneity=0.7112
# Dist=1, Ang=2.36 | Contrast=127.4831, Correlation=0.9910, Energy=0.2228, Homogeneity=0.6727
# Dist=3, Ang=0 | Contrast=83.1396, Correlation=0.9941, Energy=0.2272, Homogeneity=0.6401
# Dist=3, Ang=0.79 | Contrast=264.2893, Correlation=0.9813, Energy=0.2229, Homogeneity=0.6254
# Dist=3, Ang=1.57 | Contrast=359.0934, Correlation=0.9746, Energy=0.2211, Homogeneity=0.6279
# Dist=3, Ang=2.36 | Contrast=271.2773, Correlation=0.9808, Energy=0.2228, Homogeneity=0.6250
# Dist=5, Ang=0 | Contrast=137.7347, Correlation=0.9903, Energy=0.2238, Homogeneity=0.6094
# Dist=5, Ang=0.79 | Contrast=541.1278, Correlation=0.9619, Energy=0.2155, Homogeneity=0.5798
# Dist=5, Ang=1.57 | Contrast=604.5048, Correlation=0.9573, Energy=0.2173, Homogeneity=0.5958
# Dist=5, Ang=2.36 | Contrast=547.0706, Correlation=0.9614, Energy=0.2152, Homogeneity=0.5790
#
# Imagen: person937_bacteria_2862.jpeg | Clase: NEUMONIA
# Dist=1, Ang=0 | Contrast=28.3711, Correlation=0.9957, Energy=0.1412, Homogeneity=0.7092
# Dist=1, Ang=0.79 | Contrast=103.9870, Correlation=0.9842, Energy=0.1387, Homogeneity=0.6581
# Dist=1, Ang=1.57 | Contrast=84.0474, Correlation=0.9873, Energy=0.1388, Homogeneity=0.7119
# Dist=1, Ang=2.36 | Contrast=101.3665, Correlation=0.9846, Energy=0.1386, Homogeneity=0.6562
# Dist=3, Ang=0 | Contrast=103.8898, Correlation=0.9843, Energy=0.1409, Homogeneity=0.5948
# Dist=3, Ang=0.79 | Contrast=206.8501, Correlation=0.9687, Energy=0.1362, Homogeneity=0.5929
# Dist=3, Ang=1.57 | Contrast=257.7702, Correlation=0.9609, Energy=0.1339, Homogeneity=0.6053
# Dist=3, Ang=2.36 | Contrast=207.7910, Correlation=0.9685, Energy=0.1362, Homogeneity=0.5910
# Dist=5, Ang=0 | Contrast=157.5935, Correlation=0.9762, Energy=0.1408, Homogeneity=0.5549
# Dist=5, Ang=0.79 | Contrast=374.7110, Correlation=0.9434, Energy=0.1314, Homogeneity=0.5309
# Dist=5, Ang=1.57 | Contrast=400.4453, Correlation=0.9393, Energy=0.1291, Homogeneity=0.5589
# Dist=5, Ang=2.36 | Contrast=374.1595, Correlation=0.9435, Energy=0.1314, Homogeneity=0.5295
#
# Imagen: person423_bacteria_1855.jpeg | Clase: NEUMONIA
# Dist=1, Ang=0 | Contrast=21.7974, Correlation=0.9975, Energy=0.1048, Homogeneity=0.6729
# Dist=1, Ang=0.79 | Contrast=93.4206, Correlation=0.9894, Energy=0.0996, Homogeneity=0.6094
# Dist=1, Ang=1.57 | Contrast=77.8861, Correlation=0.9912, Energy=0.0998, Homogeneity=0.6722
# Dist=1, Ang=2.36 | Contrast=95.0223, Correlation=0.9892, Energy=0.0997, Homogeneity=0.6137
# Dist=3, Ang=0 | Contrast=86.5063, Correlation=0.9902, Energy=0.1038, Homogeneity=0.5517
# Dist=3, Ang=0.79 | Contrast=196.5887, Correlation=0.9777, Energy=0.1000, Homogeneity=0.5436
# Dist=3, Ang=1.57 | Contrast=248.6360, Correlation=0.9718, Energy=0.0974, Homogeneity=0.5554
# Dist=3, Ang=2.36 | Contrast=198.3716, Correlation=0.9775, Energy=0.1000, Homogeneity=0.5494
# Dist=5, Ang=0 | Contrast=133.0972, Correlation=0.9850, Energy=0.1035, Homogeneity=0.5094
# Dist=5, Ang=0.79 | Contrast=384.3256, Correlation=0.9565, Energy=0.0964, Homogeneity=0.4817
# Dist=5, Ang=1.57 | Contrast=412.8674, Correlation=0.9531, Energy=0.0946, Homogeneity=0.5091
# Dist=5, Ang=2.36 | Contrast=381.8450, Correlation=0.9567, Energy=0.0965, Homogeneity=0.4893

# %% [markdown]
# ## 🧩 **Construcción del vector de características final**
# Siguiendo la estructura del notebook de tu compañero, combinamos todo en un único vector.

# %%
def build_feature_vector(img):
    features = compute_glcm_features(
        img,
        distances=[1, 3, 5],
        angles=[0, np.pi/4, np.pi/2, 3*np.pi/4]
    )

    vector = []

    for f in features:
        vector.append(f['contrast'])
        vector.append(f['correlation'])
        vector.append(f['energy'])
        vector.append(f['homogeneity'])

    return np.array(vector)

# %%
feature_vectors = []
labels = []

for idx, img_name in enumerate(selected_images):

    if idx < 3:
        path = os.path.join(train_normal, img_name)
        clase = 0   # normal
    else:
        path = os.path.join(train_pneumonia, img_name)
        clase = 1   # neumonía

    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

